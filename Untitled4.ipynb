# %% [markdown]
# <a href="https://colab.research.google.com/github/prateeksharma10jan-byte/gen-ai/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_dict={"name":"amit","college":"shoolini universty"}
type(my_dict)

# %%
#keys()--this method find number of values in dictionary
list(my_dict.keys)

# %%
#items()--this method find item in dictionary
list(my_dict.items)

# %%
#update()--this method update the dictionary and take dicttionary as argument

# %%
      thee are three type of linear registration
      simolle linear
